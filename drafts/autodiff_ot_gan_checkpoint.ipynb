# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gabrielkasmi/ot_gan_ensae/blob/master/drafts/autodiff_ot_gan_checkpoint.ipynb)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable
from torchvision.utils import save_image, make_grid
import numpy as np
import matplotlib.pyplot as plt
from torchvision import datasets
import torchvision.transforms as transforms
# !pip install torchviz #git+https://github.com/szagoruyko/pytorchviz
from torchviz import make_dot
# !pip install POT
import ot
# Out:
# Requirement already satisfied: torchviz in /usr/local/lib/python3.6/dist-packages (0.0.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from torchviz) (1.5.0+cu101)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.6/dist-packages (from torchviz) (0.10.1)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch->torchviz) (0.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch->torchviz) (1.18.4)
# Requirement already satisfied: POT in /usr/local/lib/python3.6/dist-packages (0.7.0)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.6/dist-packages (from POT) (1.4.1)
# Requirement already satisfied: cython>=0.23 in /usr/local/lib/python3.6/dist-packages (from POT) (0.29.17)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.6/dist-packages (from POT) (1.18.4)

# %%
# check if cuda is available. if so, send the necessary stuff to the GPU
# warning : some cells/functions are only designed to work with Cuda
cuda = torch.cuda.is_available()

# %% [markdown]
# ### Definition of the model, import of the database

# %% [markdown]
# The model for the MLP is the same as in the paper. Two input neurons, a hidden layer with 500 units and an output layer with 784 units. We choose the ReLU activation function.

# %%
class MultilayerPerceptron(nn.Module):
    """
    A MLP with 1 hidden layer
    """
    
    def __init__(self, input_size, hidden_size, output_size):
        """
    Constructor of the MLP.
    Arguments:
    - input_size : number of neurons in the first layer 
    (aka latent space dimension)
    - hidden_size : number of neurons in the hidden layer
    - outout_size : number of neurons in the last layer
        """
        super(MultilayerPerceptron, self).__init__()
        self.input_size = input_size
        self.hidden_size  = hidden_size
        self.output_size = output_size
        self.hidden = torch.nn.Linear(self.input_size, self.hidden_size)
        self.relu = torch.nn.ReLU()
        self.output = torch.nn.Linear(self.hidden_size, self.output_size)
        self.sigmoid = torch.nn.Sigmoid()
        # self.relu = torch.nn.ReLU()
        
    def forward(self, x):
        hidden = self.hidden(x)
        relu = self.relu(hidden)
        output = self.output(relu)
        # output = self.sigmoid(output)
        # output = self.relu(output)
        return output

# %%
# Plot the graph of the network
x = torch.rand(2)
test = MultilayerPerceptron(2, 500, 28*28)
# make_dot(test.forward(x)).render('img/mlp_architecture')

# %%
# Helper to plot the images

def imshow(img):
    """
    takes a tensor as input and returns an image
    """
    if cuda:
      np_img = img.detach().cpu().numpy()
    else:
      np_img = img.detach().numpy()
    plt.imshow(np.reshape(np_img,(28,28)), cmap='gray_r' )
    plt.show()

# %%
# for i in range(10):
#     imshow(test.forward(x[i,:]))
imshow(test.forward(x))

# %% [markdown]
# As it can be seen above, without training the model essentialy generates noise.

# %%
# import the dataset

transform = transforms.ToTensor()

# get the training datasets
train_data = datasets.MNIST(root='data', train=True,
                                   download=True, transform=transform)



# number of subprocesses to use for data loading
num_workers = 0
# how many samples per batch to load
batch_size = 512

# prepare data loader
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
                                           num_workers=num_workers)

dataiter = iter(train_loader)
images, labels = dataiter.next()

images_np = images.numpy()


# get one image from the batch
img = np.squeeze(images_np[np.random.randint(len(images))])

fig = plt.figure(figsize = (3,3)) 
ax = fig.add_subplot(111)
ax.imshow(img, cmap='gray_r')
plt.show()

# %% [markdown]
# ### A first benchmark with a simple $\ell_2$ loss

# %% [markdown]
# #### Test on a batch of images

# %% [markdown]
# We first want to see whether the model works, i.e. is able to learn. To do so, we first try to learn using a simple loss and see if the results are consistent.

# %%
# test if the network is training as expected on a dummy example
# should generate an "average" image

if cuda:  
  test = MultilayerPerceptron(2, 500, 784).cuda()

criterion = torch.nn.MSELoss()
optimizer = torch.optim.Adam(test.parameters(), lr = 0.02) # same optimizer as in the paper

z_size = 2
test.train()
epochs = 25 # not necessary to put many epochs
samples_evolution = []
losses = []
for epoch in range(epochs):
    
    for batch_i, (real_images, _) in enumerate(train_loader):
        
        batch_size = real_images.size(0)
        real_images = real_images*2 - 1 # rescale the images
        real_images = real_images.view(-1, 28*28).cuda()
                
        optimizer.zero_grad()
        # Forward pass
        z = torch.rand((batch_size,z_size), requires_grad=True).cuda()
        y_pred = test(z).cuda()
            
        # Compute Loss 
        loss = criterion(y_pred, real_images) # this loss will be replaced by the sinkhorn loss
   
   
        
        # Backward pass
        loss.backward()
        optimizer.step()
    print('Epoch %s: train loss: %0.5f' %(epoch, loss.item()))
    losses.append(loss.item())
    if epoch%10==0:    
        # add an image to the list to see the improvements
        print('Generating an image after %s epochs' %epoch)
        x = torch.rand(2, requires_grad=True).cuda()
        samples_evolution.append(test.forward(x))
# Out:
# Epoch 0: train loss: 0.25643
# Generating an image after 0 epochs
# Epoch 1: train loss: 0.25712
# Epoch 2: train loss: 0.25742
# Epoch 3: train loss: 0.25784
# Epoch 4: train loss: 0.25762
# Epoch 5: train loss: 0.25634
# Epoch 6: train loss: 0.25599
# Epoch 7: train loss: 0.25546
# Epoch 8: train loss: 0.25519
# Epoch 9: train loss: 0.25500
# Epoch 10: train loss: 0.25542
# Generating an image after 10 epochs
# Epoch 11: train loss: 0.25511
# Epoch 12: train loss: 0.25577
# Epoch 13: train loss: 0.25652
# Epoch 14: train loss: 0.25733
# Epoch 15: train loss: 0.25681
# Epoch 16: train loss: 0.25686
# Epoch 17: train loss: 0.25728
# Epoch 18: train loss: 0.25781
# Epoch 19: train loss: 0.25810
# Epoch 20: train loss: 0.25862
# Generating an image after 20 epochs
# Epoch 21: train loss: 0.25887
# Epoch 22: train loss: 0.25893
# Epoch 23: train loss: 0.25901
# Epoch 24: train loss: 0.25898

# %%
# plot the images generated over training
for img in samples_evolution:
  imshow(img)

# %% [markdown]
# As expected, when evaluating against a batch of images, we end up generating "average" images.
#
# We now turn to an even simpler example where the algorithm only learns one image. The result sould be that no matter the input, the same image is returned as an output.

# %% [markdown]
# #### Test on a single image

# %%
# definition of the target image
target = real_images[0]
imshow(target)

# %%
# test if the network is training as expected on a dummy example
# even simpler test, overfit to one image.


if cuda:  
  test = MultilayerPerceptron(2, 500, 784).cuda()

criterion = torch.nn.MSELoss()
optimizer = torch.optim.Adam(test.parameters(), lr = 0.02) # same optimizer as in the paper

z_size = 2
test.train()
epochs = 10 # not necessary to put many epochs
# samples_evolution = []
#losses = []
for epoch in range(epochs):
    
    for batch_i, (real_images, _) in enumerate(train_loader):
        
        batch_size = real_images.size(0)
        real_images = real_images*2 - 1 # rescale the images
        real_images = real_images.view(-1, 28*28).cuda()
                
        optimizer.zero_grad()
        # Forward pass
        z = torch.rand((batch_size,z_size), requires_grad=True).cuda()
        y_pred = test(z).cuda()
            
        # Compute Loss 
        loss = criterion(y_pred, target.cuda()) # this loss will be replaced by the sinkhorn loss
   
        
        # Backward pass
        loss.backward()
        optimizer.step()
    print('Epoch %s: train loss: %0.5f' %(epoch, loss.item()))
    #losses.append(loss.item())
    #if epoch%10==0:    
        # add an image to the list to see the improvements
        #print('Generating an image after %s epochs' %epoch)
        #x = torch.rand(2, requires_grad=False).cuda()
        #samples_evolution.append(test(x))
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/loss.py:432: UserWarning: Using a target size (torch.Size([784])) that is different to the input size (torch.Size([512, 784])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/loss.py:432: UserWarning: Using a target size (torch.Size([784])) that is different to the input size (torch.Size([96, 784])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch 0: train loss: 0.00013
# Epoch 1: train loss: 0.00003
# Epoch 2: train loss: 0.00001
# Epoch 3: train loss: 0.00001
# Epoch 4: train loss: 0.00001
# Epoch 5: train loss: 0.00000
# Epoch 6: train loss: 0.00000
# Epoch 7: train loss: 0.00000
# Epoch 8: train loss: 0.00000
# Epoch 9: train loss: 0.00000

# %%
# generate some random vectors and some images 
# copies of the original image are indeed generated.

z = torch.rand(3,2).cuda()
target_copies = test.forward(z)

for img in target_copies:
  imshow(img)

# %% [markdown]
# ### OT-GAN implementation

# %% [markdown]
# The model seems to be working.
#
# In this section, we define our own loss based on Sinkhorn algorithm and replace it into the learning loop.

# %% [markdown]
# #### Definition of the functions
#
# Three blocks are needed : a cost matrix, the sinkhorn loop and a wrapper that computes the sinkhorn loss $\bar{W}(\mu,\nu) = 2 W(\mu,nu) - W(\mu,\mu) - W(\nu,\nu)$

# %%
# cost matrices : l2 norm and cosine distance

def cost_matrix(x, y, normalize = True):
  """
  returns the matric of |x_i-y_j|^2

  x, y : batch tensors

  normalize : true to normalize weights
  """

  
  # reshape the tensors from (bs, n) to (n, bs) 
  # for the computations 
  bs, n = x.size()
  bs2, m = y.size()
    
  x = x.view(n, bs).cuda()
  y = y.view(m, bs2).cuda()


  # compute the cost
  x_col = x.unsqueeze(-2)
  y_lin = y.unsqueeze(-3)
  C = torch.sum((torch.abs(x_col - y_lin)) ** 2, -1)

  if normalize:
    return C/max(1,C.max())

  else : 
    return C

def cosine_matrix(x,y,eps = 1e-5):
  """
  computes the cosine similarity matrix between x and y

  arguemnts:
  x, y : batches
  eps : added to avoid nans

  returns a matrix 

  """
  # reshape the tensors from (bs, n) to (n, bs) 
  # for the computations 
  bs, n = x.size()
  bs2, m = y.size()
    
  x = x.view(n, bs).cuda()
  y = y.view(m, bs2).cuda()

  return 1 - torch.mm(x,y.t())/ max(torch.norm(x, p=2)*torch.norm(y, p=2), eps)

# %%
# sinkhorn loop

def sinkhorn_distance(C, epsilon = 0.01, max_iters = 100):
  """
  Compute the sinkhorn distance between batch vectors x and y

  input : cost matrix C

  outputs : a scalar corresponding to the cost
  """

  # dimensions of the data (should be the same in our case)
  n, m = C.size()

  # Kernel matrix
  K = torch.exp(-C/epsilon).cuda()

  # Sinkhorn iterates
  a = torch.ones(m).cuda()
  b = torch.ones(n).cuda()

  #actual loop 
  v = torch.ones(n).cuda()
  for _ in range(max_iters):
    u = a / torch.mv(K,v).cuda()
    v = b / torch.mv(K.t(), u).cuda()

  M = torch.matmul(torch.matmul(torch.diag(u),K),torch.diag(v)).cuda()
  return torch.sum(M*C)

# %%
def sinkhorn_loss(x, y, epsilon = 0.1, max_iters = 50 ,normalize = True, cost = 'cosine'):
  """
  Wrapper of the two functions, returns the sinkorn loss between
  batches x and y

  cost : to be chosen between euclidean and cosine 
  """

  if cost == 'euclidean':

    # l2 norm cost matrices 
    C_xy = cost_matrix(x, y, normalize = normalize)
    C_xx = cost_matrix(x, x, normalize = normalize)
    C_yy = cost_matrix(y, y, normalize = normalize)

  elif cost == 'cosine':
    # cosine cost matrix
    C_xy = cosine_matrix(x, y)
    C_xx = cosine_matrix(x, x)
    C_yy = cosine_matrix(y, y)

  # losses

  W_xy = sinkhorn_distance(C_xy, epsilon = epsilon, max_iters = max_iters)
  W_xx = sinkhorn_distance(C_xx, epsilon = epsilon, max_iters = max_iters)
  W_yy = sinkhorn_distance(C_yy, epsilon = epsilon, max_iters = max_iters)

  return 2 * W_xy - W_xx - W_yy

# %% [markdown]
# #### Tests on the functions
#
# Before turning to the training of the model, we test our functions to see if they work properly.

# %%
untrained = MultilayerPerceptron(2,500,28*28).cuda()
z_init = torch.rand(512,2).cuda()
y_rand = untrained.forward(z_init)

# %%
# checks that the loss is nonnegative and decreasing
print(sinkhorn_loss(y_rand, real_images), sinkhorn_loss(y_rand,y_rand))
# Out:
# tensor(0.1487, device='cuda:0', grad_fn=<SubBackward0>) tensor(0., device='cuda:0', grad_fn=<SubBackward0>)

# %% [markdown]
# #### First try

# %%
# train the model with the custom loss

cuda = torch.cuda.is_available()
                                 
if cuda:  
  model2 = MultilayerPerceptron(2, 500, 784).cuda()

# training with custom loss
optimizer = torch.optim.Adam(model2.parameters(), lr = 0.02) # same optimizer as in the paper
                                                             # for the mnist experiment
z_size = 2
batch_size = 512
model2.train()
epochs = 100
samples_evolution_sk = []
losses = []
for epoch in range(epochs):
    
    for batch_i, (real_images, _) in enumerate(train_loader):
        
        #with torch.no_grad():
        batch_size = real_images.size(0)
        #real_images = real_images*2 - 1 # rescale the images
        real_images = real_images.view(-1, 28*28)
        if cuda : 
          real_images.cuda()
                
        optimizer.zero_grad()
        
        # Forward pass
        z = torch.rand((batch_size,z_size), requires_grad=True)
        if cuda :
          z = z.cuda()

        y_pred = model2(z)
            
        # Compute Loss 
        loss = sinkhorn_loss(y_pred, real_images, epsilon = 0.1) # set epsilon to 1, otherwise can lead
                                                               # to instabilities and nans

        # Backward pass
        loss.backward()
        optimizer.step()
    print('Epoch %s: train loss: %0.5f' %(epoch, loss.item()))
    losses.append(loss.item())
    if epoch%10==0:    
        # add an image to the list to see the improvements (if any)
        print('Generating an image after %s epochs' %epoch)
        x = torch.rand(2, requires_grad=False).cuda()
        samples_evolution_sk.append(model2(x))
# Out:
# Epoch 0: train loss: 0.00140
# Generating an image after 0 epochs
# Epoch 1: train loss: 0.00153
# Epoch 2: train loss: 0.00146
# Epoch 3: train loss: 0.00140
# Epoch 4: train loss: 0.00195
# Epoch 5: train loss: 0.00165
# Epoch 6: train loss: 0.00159
# Epoch 7: train loss: 0.00140
# Epoch 8: train loss: 0.00116
# Epoch 9: train loss: 0.00134
# Epoch 10: train loss: 0.00134
# Generating an image after 10 epochs
# Epoch 11: train loss: 0.00116
# Epoch 12: train loss: 0.00104
# Epoch 13: train loss: 0.00122
# Epoch 14: train loss: 0.00104
# Epoch 15: train loss: 0.00085
# Epoch 16: train loss: 0.00128
# Epoch 17: train loss: 0.00092
# Epoch 18: train loss: 0.00104
# Epoch 19: train loss: 0.00098
# Epoch 20: train loss: 0.00098
# Generating an image after 20 epochs
# Epoch 21: train loss: 0.00110
# Epoch 22: train loss: 0.00073
# Epoch 23: train loss: 0.00110
# Epoch 24: train loss: 0.00110
# Epoch 25: train loss: 0.00098
# Epoch 26: train loss: 0.00098
# Epoch 27: train loss: 0.00098
# Epoch 28: train loss: 0.00104
# Epoch 29: train loss: 0.00110
# Epoch 30: train loss: 0.00098
# Generating an image after 30 epochs
# Epoch 31: train loss: 0.00110
# Epoch 32: train loss: 0.00098
# Epoch 33: train loss: 0.00098
# Epoch 34: train loss: 0.00098
# Epoch 35: train loss: 0.00110
# Epoch 36: train loss: 0.00116
# Epoch 37: train loss: 0.00110
# Epoch 38: train loss: 0.00104
# Epoch 39: train loss: 0.00098
# Epoch 40: train loss: 0.00092
# Generating an image after 40 epochs
# Epoch 41: train loss: 0.00110
# Epoch 42: train loss: 0.00110
# Epoch 43: train loss: 0.00098
# Epoch 44: train loss: 0.00098
# Epoch 45: train loss: 0.00104
# Epoch 46: train loss: 0.00085
# Epoch 47: train loss: 0.00098
# Epoch 48: train loss: 0.00098
# Epoch 49: train loss: 0.00098
# Epoch 50: train loss: 0.00098
# Generating an image after 50 epochs
# Epoch 51: train loss: 0.00098
# Epoch 52: train loss: 0.00098
# Epoch 53: train loss: 0.00092
# Epoch 54: train loss: 0.00092
# Epoch 55: train loss: 0.00092
# Epoch 56: train loss: 0.00098
# Epoch 57: train loss: 0.00085
# Epoch 58: train loss: 0.00104
# Epoch 59: train loss: 0.00104
# Epoch 60: train loss: 0.00092
# Generating an image after 60 epochs
# Epoch 61: train loss: 0.00085
# Epoch 62: train loss: 0.00098
# Epoch 63: train loss: 0.00098
# Epoch 64: train loss: 0.00085
# Epoch 65: train loss: 0.00085
# Epoch 66: train loss: 0.00092
# Epoch 67: train loss: 0.00085
# Epoch 68: train loss: 0.00085
# Epoch 69: train loss: 0.00085
# Epoch 70: train loss: 0.00092
# Generating an image after 70 epochs
# Epoch 71: train loss: 0.00085
# Epoch 72: train loss: 0.00085
# Epoch 73: train loss: 0.00085
# Epoch 74: train loss: 0.00085
# Epoch 75: train loss: 0.00098
# Epoch 76: train loss: 0.00079
# Epoch 77: train loss: 0.00098
# Epoch 78: train loss: 0.00085
# Epoch 79: train loss: 0.00085
# Epoch 80: train loss: 0.00079
# Generating an image after 80 epochs
# Epoch 81: train loss: 0.00085
# Epoch 82: train loss: 0.00092
# Epoch 83: train loss: 0.00079
# Epoch 84: train loss: 0.00085
# Epoch 85: train loss: 0.00073
# Epoch 86: train loss: 0.00085
# Epoch 87: train loss: 0.00079
# Epoch 88: train loss: 0.00085
# Epoch 89: train loss: 0.00079
# Epoch 90: train loss: 0.00073
# Generating an image after 90 epochs
# Epoch 91: train loss: 0.00073
# Epoch 92: train loss: 0.00073
# Epoch 93: train loss: 0.00085
# Epoch 94: train loss: 0.00073
# Epoch 95: train loss: 0.00079
# Epoch 96: train loss: 0.00073
# Epoch 97: train loss: 0.00073
# Epoch 98: train loss: 0.00085
# Epoch 99: train loss: 0.00079

# %%
# plot some samples and the loss
plt.plot(losses)
plt.savefig('cosine_losses_100e_one_hidden_layer.png')

# %%
for img in samples_evolution_sk:
  imshow(img)

# %%
x = torch.rand(3,2).cuda()
generated_images = model2.forward(x)
for img in generated_images:
  imshow(img)
# not really a mnist digit, but not noise either
# problem is that it gives always the same image.

# %% [markdown]
# It appears that the model is indeed learning ; the loss is also decreasing over the epochs, which seems to be encouraging. However the results are not very satisfying.

# %% [markdown]
# #### Second try

# %% [markdown]
# We introduce a modification on the cosine cost matrix, hopefully gives better results

# %%
def cosine_matrix3(x,y):
  """
  computes the cosine similarity between batches x and y 
  """

  # get the batch size
  bs = x.size()[0]
  bs2 = y.size()[0]

  assert bs == bs2, 'batch sizes %s and %s are not the same' % (bs, bs2)

  C = torch.mm(x.cuda(),y.t().cuda()) / (torch.norm(x).cuda() * torch.norm(y).cuda())
  return (1 - C).cuda()

# %%
def sinkhorn_loss2(x, y, epsilon = 0.1, max_iters = 50 ,normalize = True, cost = 'cosine'):
  """
  Wrapper of the two functions, returns the sinkorn loss between
  batches x and y

  cost : to be chosen between euclidean and cosine 
  """

  if cost == 'euclidean':

    # l2 norm cost matrices 
    C_xy = cost_matrix(x, y, normalize = normalize)
    C_xx = cost_matrix(x, x, normalize = normalize)
    C_yy = cost_matrix(y, y, normalize = normalize)

  elif cost == 'cosine':
    # cosine cost matrix
    C_xy = cosine_matrix3(x, y)
    C_xx = cosine_matrix3(x, x)
    C_yy = cosine_matrix3(y, y)

  # losses

  W_xy = sinkhorn_distance(C_xy, epsilon = epsilon, max_iters = max_iters)
  W_xx = sinkhorn_distance(C_xx, epsilon = epsilon, max_iters = max_iters)
  W_yy = sinkhorn_distance(C_yy, epsilon = epsilon, max_iters = max_iters)

  return 2 * W_xy - W_xx - W_yy

# %%
untrained = MultilayerPerceptron(2,500,28*28).cuda()
z_init = torch.rand(512,2).cuda()
y_rand = untrained.forward(z_init)

# checks that the loss is nonnegative and decreasing
print(sinkhorn_loss2(y_rand, real_images), sinkhorn_loss2(y_rand,y_rand))
# Out:
# tensor(1.3049, device='cuda:0', grad_fn=<SubBackward0>) tensor(0., device='cuda:0', grad_fn=<SubBackward0>)

# %%
# train the model with the custom loss

cuda = torch.cuda.is_available()
                                 
if cuda:  
  model3 = MultilayerPerceptron(2, 500, 784).cuda()

# training with custom loss
optimizer = torch.optim.Adam(model3.parameters(), lr = 0.02) # same optimizer as in the paper
                                                             # for the mnist experiment
z_size = 2
batch_size = 512
model3.train()
epochs = 100
samples_evolution_sk = []
losses = []
for epoch in range(epochs):
    
    for batch_i, (real_images, _) in enumerate(train_loader):
        
        #with torch.no_grad():
        batch_size = real_images.size(0)
        #real_images = real_images*2 - 1 # rescale the images
        real_images = real_images.view(-1, 28*28)
        if cuda : 
          real_images.cuda()
                
        optimizer.zero_grad()
        
        # Forward pass
        z = torch.rand((batch_size,z_size), requires_grad=True)
        if cuda :
          z = z.cuda()

        y_pred = model3(z)
            
        # Compute Loss 
        loss = Variable(sinkhorn_loss2(y_pred, real_images, epsilon = 0.1), requires_grad = True) 
                                                              # set epsilon to 0.1, otherwise can lead
                                                               # to instabilities and nans

        # Backward pass
        loss.backward()
        optimizer.step()
    print('Epoch %s: train loss: %0.5f' %(epoch, loss.item()))
    losses.append(loss.item())
    if epoch%10==0:    
        # add an image to the list to see the improvements (if any)
        print('Generating an image after %s epochs' %epoch)
        x = torch.rand(2, requires_grad=False).cuda()
        samples_evolution_sk.append(model3.forward(x))
# Out:
# Epoch 0: train loss: 1.29924
# Generating an image after 0 epochs
# Epoch 1: train loss: 1.30431
# Epoch 2: train loss: 1.30571
# Epoch 3: train loss: 1.30060
# Epoch 4: train loss: 1.30925
# Epoch 5: train loss: 1.29066
# Epoch 6: train loss: 1.29901
# Epoch 7: train loss: 1.30426
# Epoch 8: train loss: 1.30017
# Epoch 9: train loss: 1.30624
# Epoch 10: train loss: 1.29933
# Generating an image after 10 epochs
# Epoch 11: train loss: 1.29318
# Epoch 12: train loss: 1.30502
# Epoch 13: train loss: 1.29578
# Epoch 14: train loss: 1.31438
# Epoch 15: train loss: 1.30185
# Epoch 16: train loss: 1.30792
# Epoch 17: train loss: 1.29724
# Epoch 18: train loss: 1.30110
# Epoch 19: train loss: 1.29482
# Epoch 20: train loss: 1.30219
# Generating an image after 20 epochs
# Epoch 21: train loss: 1.30737
# Epoch 22: train loss: 1.29056
# Epoch 23: train loss: 1.30445
# Epoch 24: train loss: 1.30597
# Epoch 25: train loss: 1.30850
# Epoch 26: train loss: 1.30429
# Epoch 27: train loss: 1.30306
# Epoch 28: train loss: 1.29928
# Epoch 29: train loss: 1.30616
# Epoch 30: train loss: 1.30644
# Generating an image after 30 epochs
# Epoch 31: train loss: 1.30582
# Epoch 32: train loss: 1.29839
# Epoch 33: train loss: 1.29752
# Epoch 34: train loss: 1.30844
# Epoch 35: train loss: 1.29992
# Epoch 36: train loss: 1.30110
# Epoch 37: train loss: 1.30337
# Epoch 38: train loss: 1.30082
# Epoch 39: train loss: 1.30424
# Epoch 40: train loss: 1.29787
# Generating an image after 40 epochs
# Epoch 41: train loss: 1.30435
# Epoch 42: train loss: 1.30421
# Epoch 43: train loss: 1.29805
# Epoch 44: train loss: 1.29909
# Epoch 45: train loss: 1.28513
# Epoch 46: train loss: 1.31030
# Epoch 47: train loss: 1.30527
# Epoch 48: train loss: 1.30079
# Epoch 49: train loss: 1.30758
# Epoch 50: train loss: 1.30001
# Generating an image after 50 epochs
# Epoch 51: train loss: 1.30306
# Epoch 52: train loss: 1.30225
# Epoch 53: train loss: 1.28897
# Epoch 54: train loss: 1.29997
# Epoch 55: train loss: 1.30748
# Epoch 56: train loss: 1.29314
# Epoch 57: train loss: 1.30353
# Epoch 58: train loss: 1.29912
# Epoch 59: train loss: 1.30070
# Epoch 60: train loss: 1.29651
# Generating an image after 60 epochs
# Epoch 61: train loss: 1.30156
# Epoch 62: train loss: 1.30182
# Epoch 63: train loss: 1.30125
# Epoch 64: train loss: 1.30286
# Epoch 65: train loss: 1.30387
# Epoch 66: train loss: 1.30212
# Epoch 67: train loss: 1.30383
# Epoch 68: train loss: 1.30904
# Epoch 69: train loss: 1.30237
# Epoch 70: train loss: 1.31078
# Generating an image after 70 epochs
# Epoch 71: train loss: 1.30228
# Epoch 72: train loss: 1.31190
# Epoch 73: train loss: 1.30303
# Epoch 74: train loss: 1.30243
# Epoch 75: train loss: 1.30162
# Epoch 76: train loss: 1.29994
# Epoch 77: train loss: 1.30847
# Epoch 78: train loss: 1.30592
# Epoch 79: train loss: 1.29808
# Epoch 80: train loss: 1.30847
# Generating an image after 80 epochs
# Epoch 81: train loss: 1.30720
# Epoch 82: train loss: 1.29974
# Epoch 83: train loss: 1.30006
# Epoch 84: train loss: 1.30557
# Epoch 85: train loss: 1.29953
# Epoch 86: train loss: 1.31268
# Epoch 87: train loss: 1.29681
# Epoch 88: train loss: 1.30533
# Epoch 89: train loss: 1.29724
# Epoch 90: train loss: 1.30519
# Generating an image after 90 epochs
# Epoch 91: train loss: 1.29799
# Epoch 92: train loss: 1.30141
# Epoch 93: train loss: 1.30298
# Epoch 94: train loss: 1.30191
# Epoch 95: train loss: 1.29744
# Epoch 96: train loss: 1.29924
# Epoch 97: train loss: 1.31081
# Epoch 98: train loss: 1.30505
# Epoch 99: train loss: 1.29813

# %%
# plot some samples and the loss
plt.plot(losses)
plt.savefig('cosine_losses_100e_one_hidden_layer_batch_matrix.png') 
# doesn't really seem to be learning at all

# %%
x = torch.rand(3,2).cuda()
generated_images = model3.forward(x)
for img in generated_images:
  imshow(img)

# %% [markdown]
# Its getting worse... Try, again, with a $\ell_2$ loss over the batches to see if there is any improvement

# %% [markdown]
# #### Thrid try
#
# Change again the cost matrix, to be the $\ell_2$ distances over the batches

# %%
def cost_matrix4(x,y, normalize = True):
  """
  euclidean cost matrix between batches 
  """

  C = torch.cdist(x,y).cuda()
  
  if normalize: 
    return C/max(1,C.max())
  else:
    return C
# sinkhorn loop

def sinkhorn_distance2(C, epsilon = 0.01, max_iters = 100):
  """
  Compute the sinkhorn distance between batch vectors x and y
  
  input : cost matrix C

  outputs : a scalar corresponding to the cost
  edited version with the propagation removed from the 
  sinkhorn iterates (speeds up the computations)
  """
  # dimensions of the data (should be the same in our case)
  n, m = C.size()

  # Sinkhorn iterates
  a = torch.ones(m).cuda()
  b = torch.ones(n).cuda()

  #actual loop 
  v = torch.ones(n).cuda()

  with torch.no_grad():
    K = torch.exp(-C/epsilon).cuda()
    for _ in range(max_iters):
      u = a / torch.mv(K,v).cuda()
      v = b / torch.mv(K.t(), u).cuda()

  M = torch.matmul(torch.matmul(torch.diag(u),K),torch.diag(v)).cuda()
  return torch.sum(M*C)

def sinkhorn_loss3(x, y, epsilon = 0.1, max_iters = 50 ,normalize = False):
  """
  Wrapper of the two functions, returns the sinkorn loss between
  batches x and y

  cost : to be chosen between euclidean and cosine 
  """
  C_xy = cost_matrix4(x, y, normalize = normalize)
  C_xx = cost_matrix4(x, x, normalize = normalize)
  C_yy = cost_matrix4(y, y, normalize = normalize)



  # losses

  W_xy = sinkhorn_distance2(C_xy, epsilon = epsilon, max_iters = max_iters)
  W_xx = sinkhorn_distance2(C_xx, epsilon = epsilon, max_iters = max_iters)
  W_yy = sinkhorn_distance2(C_yy, epsilon = epsilon, max_iters = max_iters)

  return 2 * W_xy - W_xx - W_yy

# %%
C = cost_matrix4(real_images.cuda(), y_pred, normalize = True)
print(sinkhorn_distance2(C))
print(sinkhorn_loss3(real_images.cuda(), y_pred, normalize = True), sinkhorn_loss3(y_pred, y_pred, normalize = True))
# Out:
# tensor(353.7366, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(500.0428, device='cuda:0', grad_fn=<SubBackward0>) tensor(0., device='cuda:0', grad_fn=<SubBackward0>)

# %%
# train the model with the custom loss

cuda = torch.cuda.is_available()
                                 
if cuda:  
  model4 = MultilayerPerceptron(2, 500, 784).cuda()

# training with custom loss
optimizer = torch.optim.Adam(model4.parameters(), lr = 0.02) # same optimizer as in the paper
                                                             # for the mnist experiment
z_size = 2
batch_size = 512
model4.train()
epochs = 100
samples_evolution_sk = []
losses = []
for epoch in range(epochs):
    
    for batch_i, (real_images, _) in enumerate(train_loader):
        
        #with torch.no_grad():
        batch_size = real_images.size(0)
        #real_images = real_images*2 - 1 # rescale the images
        real_images = real_images.view(-1, 28*28)
        if cuda : 
          real_images.cuda()
                
        optimizer.zero_grad()
        
        # Forward pass
        z = torch.rand((batch_size,z_size), requires_grad=True)
        if cuda :
          z = z.cuda()

        y_pred = model4(z)
            
        # Compute Loss 
        loss = Variable(sinkhorn_loss3(y_pred, real_images.cuda(), epsilon = 0.1, normalize = True ), requires_grad = True) 
                                                              # set epsilon to .1, otherwise can lead
                                                               # to instabilities and nans

        # Backward pass
        loss.backward()
        optimizer.step()
    print('Epoch %s: train loss: %0.5f' %(epoch, loss.item()))
    losses.append(loss.item())
    if epoch%10==0:    
        # add an image to the list to see the improvements (if any)
        print('Generating an image after %s epochs' %epoch)
        x = torch.rand(2, requires_grad=False).cuda()
        samples_evolution_sk.append(model4.forward(x))
# Out:
# Epoch 0: train loss: 125.66752
# Generating an image after 0 epochs
# Epoch 1: train loss: 124.17762
# Epoch 2: train loss: 124.00495
# Epoch 3: train loss: 126.98512
# Epoch 4: train loss: 124.02462
# Epoch 5: train loss: 127.28472
# Epoch 6: train loss: 124.90665
# Epoch 7: train loss: 124.97625
# Epoch 8: train loss: 124.83451
# Epoch 9: train loss: 126.57966
# Epoch 10: train loss: 125.65772
# Generating an image after 10 epochs
# Epoch 11: train loss: 125.71099
# Epoch 12: train loss: 126.88020
# Epoch 13: train loss: 125.22829
# Epoch 14: train loss: 124.41062
# Epoch 15: train loss: 126.27831
# Epoch 16: train loss: 127.32117
# Epoch 17: train loss: 124.94508
# Epoch 18: train loss: 125.95229
# Epoch 19: train loss: 126.45821
# Epoch 20: train loss: 123.44837
# Generating an image after 20 epochs
# Epoch 21: train loss: 124.80553
# Epoch 22: train loss: 124.77287
# Epoch 23: train loss: 124.59388
# Epoch 24: train loss: 124.38223
# Epoch 25: train loss: 124.69382
# Epoch 26: train loss: 126.35221
# Epoch 27: train loss: 123.44593
# Epoch 28: train loss: 126.04450
# Epoch 29: train loss: 126.34110
# Epoch 30: train loss: 123.13880
# Generating an image after 30 epochs
# Epoch 31: train loss: 124.08285
# Epoch 32: train loss: 124.04179
# Epoch 33: train loss: 125.31583
# Epoch 34: train loss: 124.72750
# Epoch 35: train loss: 124.95158
# Epoch 36: train loss: 126.48595
# Epoch 37: train loss: 123.86317
# Epoch 38: train loss: 126.23573
# Epoch 39: train loss: 124.67626
# Epoch 40: train loss: 123.76571
# Generating an image after 40 epochs
# Epoch 41: train loss: 126.36941
# Epoch 42: train loss: 125.88831
# Epoch 43: train loss: 125.66904
# Epoch 44: train loss: 124.75907
# Epoch 45: train loss: 125.85877
# Epoch 46: train loss: 126.75523
# Epoch 47: train loss: 124.34385
# Epoch 48: train loss: 123.70580
# Epoch 49: train loss: 125.63493
# Epoch 50: train loss: 125.46792
# Generating an image after 50 epochs
# Epoch 51: train loss: 127.23846
# Epoch 52: train loss: 124.81016
# Epoch 53: train loss: 124.42365
# Epoch 54: train loss: 127.68964
# Epoch 55: train loss: 125.09615
# Epoch 56: train loss: 126.71325
# Epoch 57: train loss: 125.46502
# Epoch 58: train loss: 124.11622
# Epoch 59: train loss: 125.98142
# Epoch 60: train loss: 127.14849
# Generating an image after 60 epochs
# Epoch 61: train loss: 125.22047
# Epoch 62: train loss: 126.28608
# Epoch 63: train loss: 125.21606
# Epoch 64: train loss: 126.18946
# Epoch 65: train loss: 125.37060
# Epoch 66: train loss: 126.17731
# Epoch 67: train loss: 125.32059
# Epoch 68: train loss: 123.90240
# Epoch 69: train loss: 123.98324
# Epoch 70: train loss: 123.94465
# Generating an image after 70 epochs
# Epoch 71: train loss: 123.27877
# Epoch 72: train loss: 125.60311
# Epoch 73: train loss: 125.87034
# Epoch 74: train loss: 124.91900
# Epoch 75: train loss: 125.22297
# Epoch 76: train loss: 126.79810
# Epoch 77: train loss: 125.91599
# Epoch 78: train loss: 124.97224
# Epoch 79: train loss: 124.57665
# Epoch 80: train loss: 126.19959
# Generating an image after 80 epochs
# Epoch 81: train loss: 124.61253
# Epoch 82: train loss: 127.42785
# Epoch 83: train loss: 124.41621
# Epoch 84: train loss: 124.40119
# Epoch 85: train loss: 124.69819
# Epoch 86: train loss: 124.39715
# Epoch 87: train loss: 124.95406
# Epoch 88: train loss: 125.80441
# Epoch 89: train loss: 125.93581
# Epoch 90: train loss: 125.53129
# Generating an image after 90 epochs
# Epoch 91: train loss: 124.22149
# Epoch 92: train loss: 124.48472
# Epoch 93: train loss: 128.29538
# Epoch 94: train loss: 123.17765
# Epoch 95: train loss: 124.04844
# Epoch 96: train loss: 125.49865
# Epoch 97: train loss: 125.05717
# Epoch 98: train loss: 124.03265
# Epoch 99: train loss: 125.03022

# %%
# plot some samples and the loss
plt.plot(losses)
plt.savefig('euclidean_losses_100e_one_hidden_layer_batch_matrix.png') 
# doesn't really seem to be learning at all

# %%
for img in samples_evolution_sk:
  imshow(img)

# %% [markdown]
# #### Fourth try
#
# Euclidean cost on the samples
#
# It appears that no matter the cost matrix (cosine or euclidean) the model doesn't learn when the cost is computed over the batches.

# %%
def cost_matrix5(x,y, normalize = True):
  """
  euclidean cost matrix between batches 
  """

  # take the means over the batches
  x_mean = x.view(784, -1)
  y_mean = y.view(784, -1)

  C = torch.cdist(x_mean, y_mean).cuda()

  if normalize:
    return C / max(1, C.max())
  else: 
    return C
  
    
# sinkhorn loop

def sinkhorn_distance2(C, epsilon = 0.01, max_iters = 100):
  """
  Compute the sinkhorn distance between batch vectors x and y
  
  input : cost matrix C

  outputs : a scalar corresponding to the cost
  edited version with the propagation removed from the 
  sinkhorn iterates (speeds up the computations)
  """
  # dimensions of the data (should be the same in our case)
  n, m = C.size()

  # Sinkhorn iterates
  a = torch.ones(m).cuda()
  b = torch.ones(n).cuda()

  #actual loop 
  v = torch.ones(n).cuda()

  
  K = torch.exp(-C/epsilon).cuda()
  for _ in range(max_iters):
    u = a / ((torch.mv(K,v)) + 1e-5).cuda()
    v = b / (torch.mv(K.t(), u) + 1e-5).cuda()

  M = torch.matmul(torch.matmul(torch.diag(u),K),torch.diag(v)).cuda()
  return torch.sum(M*C)

def sinkhorn_loss4(x, y, epsilon = 0.1, max_iters = 50 ,normalize = True):
  """
  Wrapper of the two functions, returns the sinkorn loss between
  batches x and y

  cost : to be chosen between euclidean and cosine 
  """
  C_xy = cost_matrix(x, y, normalize = normalize)
  C_xx = cost_matrix(x, x, normalize = normalize)
  C_yy = cost_matrix(y, y, normalize = normalize)

  # losses

  W_xy = sinkhorn_distance2(C_xy, epsilon = epsilon, max_iters = max_iters)
  W_xx = sinkhorn_distance2(C_xx, epsilon = epsilon, max_iters = max_iters)
  W_yy = sinkhorn_distance2(C_yy, epsilon = epsilon, max_iters = max_iters)

  return 2 * W_xy - W_xx - W_yy

# %%
untrained = MultilayerPerceptron(2,500,28*28).cuda()
z = torch.rand(512, 2).cuda()
y_rand = untrained.forward(z)

C = cost_matrix5(real_images.cuda(), y_rand)
C.size()
# Out:
# torch.Size([784, 784])

# %%
sinkhorn_distance2(C)
sinkhorn_distance2(y_rand, real_images.cuda())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-61-42f7bd97855f> in <module>()
#       1 sinkhorn_distance2(C)
# ----> 2 sinkhorn_distance2(y_rand, real_images.cuda())
#
# <ipython-input-59-11d752f2475e> in sinkhorn_distance2(C, epsilon, max_iters)
#      41   K = torch.exp(-C/epsilon).cuda()
#      42   for _ in range(max_iters):
# ---> 43     u = a / ((torch.mv(K,v)) + 1e-5).cuda()
#      44     v = b / (torch.mv(K.t(), u) + 1e-5).cuda()
#      45
#
# RuntimeError: size mismatch at /pytorch/aten/src/THC/generic/THCTensorMathBlas.cu:67

# %%
# train the model with the custom loss

cuda = torch.cuda.is_available()
                                 
if cuda:  
  model4 = MultilayerPerceptron(2, 500, 784).cuda()

# training with custom loss
optimizer = torch.optim.Adam(model4.parameters(), lr = 0.02) # same optimizer as in the paper
                                                             # for the mnist experiment
z_size = 2
batch_size = 512
model4.train()
epochs = 100
samples_evolution_sk = []
losses = []
for epoch in range(epochs):
    
    for batch_i, (real_images, _) in enumerate(train_loader):
        
        #with torch.no_grad():
        batch_size = real_images.size(0)
        #real_images = real_images*2 - 1 # rescale the images
        real_images = real_images.view(-1, 28*28)
        if cuda : 
          real_images.cuda()
                
        optimizer.zero_grad()
        
        # Forward pass
        z = torch.rand((batch_size,z_size), requires_grad=True)
        if cuda :
          z = z.cuda()

        y_pred = model4(z)
            
        # Compute Loss 
        loss = sinkhorn_loss4(y_pred, real_images.cuda(), epsilon = 0.1, normalize = True )
                                                              # set epsilon to .1, otherwise can lead
                                                               # to instabilities and nans

        # something is wrong with the differentiation of the loss...
        # either the Variable() wrapping leads to no learning (because this method clears the differentiation graph)
        # otherwise exploding gradient, so back to square 1
        # with the "original" L2 normalized cost matrix, the loss is negative (!)
        # Backward pass
        loss.backward()
        optimizer.step()
    print('Epoch %s: train loss: %0.5f' %(epoch, loss.item()))
    losses.append(loss.item())
    if epoch%10==0:    
        # add an image to the list to see the improvements (if any)
        print('Generating an image after %s epochs' %epoch)
        x = torch.rand(2, requires_grad=False).cuda()
        samples_evolution_sk.append(model4.forward(x))
# Out:
# Epoch 0: train loss: -21.47392
# Generating an image after 0 epochs
# Epoch 1: train loss: -53.35881
# Epoch 2: train loss: -83.19278
# Epoch 3: train loss: -105.88770
# Epoch 4: train loss: -92.42191
# Epoch 5: train loss: -69.41348
# Epoch 6: train loss: -100.67697
# Epoch 7: train loss: -85.28102
# Epoch 8: train loss: -96.59167
# Epoch 9: train loss: -115.34599
# Epoch 10: train loss: -99.13016
# Generating an image after 10 epochs
# Epoch 11: train loss: -115.50488
# Epoch 12: train loss: -108.12604
# Epoch 13: train loss: -119.24643
# Epoch 14: train loss: -98.46637
# Epoch 15: train loss: -107.03560
# Epoch 16: train loss: -94.73712
# Epoch 17: train loss: -72.93307
# Epoch 18: train loss: -117.87201
# Epoch 19: train loss: -123.66495
# Epoch 20: train loss: -115.59647
# Generating an image after 20 epochs
# Epoch 21: train loss: -111.62196
# Epoch 22: train loss: -107.02284
# Epoch 23: train loss: -95.29613
# Epoch 24: train loss: -91.48981
# Epoch 25: train loss: -108.83234
# Epoch 26: train loss: -109.70139
# Epoch 27: train loss: -104.73737
# Epoch 28: train loss: -99.85223
# Epoch 29: train loss: -105.22234
# Epoch 30: train loss: -116.44331
# Generating an image after 30 epochs
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-a8d77de6044a> in <module>()
#      43         # otherwise exploding gradient, so back to square 1
#      44         # Backward pass
# ---> 45         loss.backward()
#      46         optimizer.step()
#      47     print('Epoch %s: train loss: %0.5f' %(epoch, loss.item()))
#
# /usr/local/lib/python3.6/dist-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     196                 products. Defaults to ``False``.
#     197         """
# --> 198         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     199
#     200     def register_hook(self, hook):
#
# /usr/local/lib/python3.6/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      98     Variable._execution_engine.run_backward(
#      99         tensors, grad_tensors, retain_graph, create_graph,
# --> 100         allow_unreachable=True)  # allow_unreachable flag
#     101
#     102
#
# KeyboardInterrupt:

# %%
# plot some samples and the loss
plt.plot(losses)
plt.savefig('euclidean_losses_100e_one_hidden_layer.png') 
# doesn't really seem to be learning at all

# %%
for img in samples_evolution_sk:
  imshow(img)

# hard to tell if there is any improvement. But still far from a mnist digit.

# %% [markdown]
# So far we've tried several implementations, none of which giving satisfying results. The approaches so far are the following:
# <ul>
# <li> Cosine cost computed on the observations : this seemed to give some results. However, the same image is generated no matter the initial position in the latent space.</li>
# <li> Cosine cost computed over the batches </li>
# <li> Euclidean cost computed on the batches </li>
# <li> Euclideal cost computed on the observations</li>
#
# </ul>
#
# The puzzling thing is that one approach is "working" (at least converging into something), but not the three other approaches. We might suspect that something is wrong with the differentiation. Somehow something is not made correctly.
#
# The problem is somewhere in the computation of the gradients when the loss is computed.

# %% [markdown]
# #### Fifth try
#
# We do things differently and define a class for the losses. We step back and use the functions of the second try (cosine on batches)

# %%
class CosineCostMatrix(nn.Module):
  def __init__(self):
    super(CosineCostMatrix,self).__init__()

  def forward(self, x,y):
    """
    takes x and y tensors as inputs and returns the cosine similarity
    """
    return 1 - torch.mm(x.cuda(),y.t().cuda()) / (torch.norm(x).cuda() * torch.norm(y).cuda())

# %%
class SinkhornIterates(nn.Module):
  def __init__(self):
    super(SinkhornIterates,self).__init__()

  def forward(self, C, epsilon = 0.1, max_iters = 100):
    """
    Computes the approximate transport plan and the 
    associated cost based on distance matrix C 
    """

    # dimensions of the data (should be the same in our case)
    n, m = C.size()

    # Sinkhorn iterates
    a = torch.ones(m).cuda()
    b = torch.ones(n).cuda()

    #actual loop 
    v = torch.ones(n).cuda()

    K = torch.exp(-C/epsilon)
    for _ in range(max_iters):
      u = a / torch.mv(K,v).cuda()
      v = b / torch.mv(K.t(), u).cuda()

    M = torch.matmul(torch.matmul(torch.diag(u),K),torch.diag(v)).cuda()
    return torch.sum(M*C)

# %%
class SinkhornLoss(nn.Module):
  def __init__(self):
    super(SinkhornLoss,self).__init__()

  def forward(self, x,y, epsilon = 0.1, max_iters = 100):
    cost_matrix = CosineCostMatrix()
    sinkhorn_iterates = SinkhornIterates()

    # computation of the distance matrices
    C_xy = cost_matrix(x, y)
    C_xx = cost_matrix(x, x)
    C_yy = cost_matrix(y, y)

    # computation of the losses 

    W_xy = sinkhorn_iterates(C_xy, epsilon = epsilon, max_iters = max_iters)
    W_xx = sinkhorn_iterates(C_xx, epsilon = epsilon, max_iters = max_iters)
    W_yy = sinkhorn_iterates(C_yy, epsilon = epsilon, max_iters = max_iters)

    return 2 * W_xy - W_xx - W_yy

# %%
# train the model with the custom loss

new_model = MultilayerPerceptron(2, 500, 784).cuda()

# training with custom loss
optimizer = torch.optim.Adam(new_model.parameters(), lr = 0.000002) 
criterion = SinkhornLoss()

z_size = 2
new_model.train()
epochs = 50
samples_evolution_sk = []
losses = []
for epoch in range(epochs):
    
    for batch_i, (real_images, _) in enumerate(train_loader):
        
        #with torch.no_grad():
        batch_size = real_images.size(0)
        # real_images = real_images*2 - 1 # rescale the images
        real_images = real_images.view(-1, 28*28)
        real_images.cuda()

        optimizer.zero_grad()
        
        # Forward pass
        z = torch.rand((batch_size,z_size), requires_grad=True).cuda()
        y_pred = new_model(z)
            
        # Compute Loss 
        loss = criterion(y_pred, real_images)

        loss.backward()
        optimizer.step()

    print('Epoch %s: train loss: %0.5f' %(epoch, loss.item()))
    losses.append(loss.item())
    if epoch%10==0:    
        # add an image to the list to see the improvements (if any)
        print('Generating an image after %s epochs' %epoch)
        x = torch.rand(2, requires_grad=False).cuda()
        samples_evolution_sk.append(new_model.forward(x))
# Out:
# Epoch 0: train loss: 1.26514
# Generating an image after 0 epochs
# Epoch 1: train loss: 1.14716
# Epoch 2: train loss: 1.03140
# Epoch 3: train loss: 0.91560
# Epoch 4: train loss: 0.79942
# Epoch 5: train loss: 0.70644
# Epoch 6: train loss: 0.59315
# Epoch 7: train loss: 0.50616
# Epoch 8: train loss: 0.42525
# Epoch 9: train loss: 0.36783
# Epoch 10: train loss: 0.31279
# Generating an image after 10 epochs
# Epoch 11: train loss: 0.27234
# Epoch 12: train loss: 0.23714
# Epoch 13: train loss: 0.20216
# Epoch 14: train loss: 0.18137
# Epoch 15: train loss: 0.16783
# Epoch 16: train loss: 0.16007
# Epoch 17: train loss: 0.16294
# Epoch 18: train loss: 0.13245
# Epoch 19: train loss: 0.12038
# Epoch 20: train loss: 0.11741
# Generating an image after 20 epochs
# Epoch 21: train loss: 0.11900
# Epoch 22: train loss: 0.11443
# Epoch 23: train loss: 0.11043
# Epoch 24: train loss: 0.10939
# Epoch 25: train loss: 0.11119
# Epoch 26: train loss: 0.11597
# Epoch 27: train loss: 0.11208
# Epoch 28: train loss: 0.10642
# Epoch 29: train loss: 0.11896
# Epoch 30: train loss: 0.11711
# Generating an image after 30 epochs
# Epoch 31: train loss: 0.11364
# Epoch 32: train loss: 0.11027
# Epoch 33: train loss: 0.10555
# Epoch 34: train loss: 0.10946
# Epoch 35: train loss: 0.10821
# Epoch 36: train loss: 0.10718
# Epoch 37: train loss: 0.11099
# Epoch 38: train loss: 0.10554
# Epoch 39: train loss: 0.11118
# Epoch 40: train loss: 0.11133
# Generating an image after 40 epochs
# Epoch 41: train loss: 0.11502
# Epoch 42: train loss: 0.11063
# Epoch 43: train loss: 0.10778
# Epoch 44: train loss: 0.11485
# Epoch 45: train loss: 0.10863
# Epoch 46: train loss: 0.10696
# Epoch 47: train loss: 0.10558
# Epoch 48: train loss: 0.12207
# Epoch 49: train loss: 0.10665

# %%
plt.plot(losses)
plt.savefig('losses_with_new_loss_50e_lr_very_low_batch_512_unormalized.png')

# stopped learning at some point.

# %%
for img in samples_evolution_sk:
  imshow(img)

# %%
x = torch.rand(4,2).cuda()
generated_images = new_model.forward(x)
for img in generated_images:
  imshow(img)
# not really a mnist digit, but not noise either
# also seems to give different numbers

# %% [markdown]
# It indeed work better but the results are not very satisfying. A possible explanation might be that the range of the cosine matrix is too narrow, so the model is eventually stuck somewhere and doesn't learn anymore.

# %% [markdown]
# #### Sixth try
#
# Some improvements, but try another cost matrix to see if there is any improvement

# %%
class EuclideanCostMatrix(nn.Module):
  def __init__(self):
    super(EuclideanCostMatrix,self).__init__()

  def forward(self, x, y):
    """
    takes x and y tensors as inputs and returns the normalized
    euclidean distance across batches
    """
    C = torch.cdist(x,y).cuda()

    return C

class SinkhornIterates(nn.Module):
  def __init__(self):
    super(SinkhornIterates,self).__init__()

  def forward(self, C, epsilon = 0.1, max_iters = 50):
    """
    Computes the approximate transport plan and the 
    associated cost based on distance matrix C 
    """

    # dimensions of the data (should be the same in our case)
    n, m = C.size()

    # Sinkhorn iterates
    a = torch.ones(m).cuda()
    b = torch.ones(n).cuda()

    #actual loop 
    v = torch.ones(n).cuda()

    K = torch.exp(-C/epsilon)
    for _ in range(max_iters):
      u = a / torch.mv(K,v).cuda()
      v = b / torch.mv(K.t(), u).cuda()

    M = torch.matmul(torch.matmul(torch.diag(u),K),torch.diag(v)).cuda()
    return torch.sum(M*C)



class SinkhornEuclideanLoss(nn.Module):
  def __init__(self):
    super(SinkhornEuclideanLoss,self).__init__()

  def forward(self, x,y, epsilon = 0.1, max_iters = 50):
    cost_matrix = EuclideanCostMatrix()
    sinkhorn_iterates = SinkhornIterates()

    # computation of the distance matrices
    C_xy = cost_matrix(x, y)
    C_xx = cost_matrix(x, x)
    C_yy = cost_matrix(y, y)

    # computation of the losses 

    W_xy = sinkhorn_iterates(C_xy, epsilon = epsilon, max_iters = max_iters)
    W_xx = sinkhorn_iterates(C_xx, epsilon = epsilon, max_iters = max_iters)
    W_yy = sinkhorn_iterates(C_yy, epsilon = epsilon, max_iters = max_iters)

    return 2 * W_xy - W_xx - W_yy

# %%
untrained = MultilayerPerceptron(2,500,28*28).cuda()
z1 = torch.rand(96,2).cuda()
z2 = torch.rand(96,2).cuda()
y_rand1 = untrained(z1)
y_rand2 = untrained(z2)


cost_mat = EuclideanCostMatrix()
C = cost_mat(y_rand1, y_rand2)

sinkhorn = SinkhornIterates()
sinkhorn(C)
C
# Out:
# tensor([[1.4369, 2.2432, 2.3063,  ..., 0.5032, 1.4584, 1.1791],
#         [2.4234, 2.7343, 1.4332,  ..., 1.4860, 2.0232, 2.0488],
#         [0.3402, 2.2392, 3.3574,  ..., 0.7176, 1.6023, 0.8694],
#         ...,
#         [1.4542, 0.8556, 3.4073,  ..., 1.4892, 0.7756, 0.7999],
#         [1.6440, 2.6540, 4.9715,  ..., 2.5220, 2.5735, 2.0482],
#         [2.7942, 1.3445, 1.9843,  ..., 2.0691, 1.2218, 1.9344]],
#        device='cuda:0', grad_fn=<ViewBackward>)

# %%
# train the model with the custom loss

cuda = torch.cuda.is_available()
                                  
new_model2 = MultilayerPerceptron(2, 500, 784).cuda()

# training with custom loss
optimizer = torch.optim.Adam(new_model2.parameters(), lr = 0.000002) 
criterion = SinkhornEuclideanLoss()

z_size = 2
batch_size = 512
new_model2.train()
epochs = 100
samples_evolution_sk = []
losses = []
for epoch in range(epochs):
    
    for batch_i, (real_images, _) in enumerate(train_loader):
        
        #with torch.no_grad():
        batch_size = real_images.size(0)
        #real_images = real_images*2 - 1 # rescale the images
        real_images = real_images.view(-1, 28*28)
        real_images.cuda()

        optimizer.zero_grad()
        
        # Forward pass
        z = torch.rand((batch_size,z_size), requires_grad=True).cuda()
        y_pred = new_model2(z)
            
        # Compute Loss 
        loss = criterion(y_pred, real_images)

        loss.backward()
        optimizer.step()
        
    print('Epoch %s: train loss: %0.5f' %(epoch, loss.item()))
    losses.append(loss.item())
    if epoch%10==0:    
        # add an image to the list to see the improvements (if any)
        print('Generating an image after %s epochs' %epoch)
        x = torch.rand(2, requires_grad=False).cuda()
        samples_evolution_sk.append(new_model2.forward(x))
# Out:
# tensor(nan, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<SubBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<SubBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-126-8d82314f0004> in <module>()
#      34         print(loss)
#      35
# ---> 36         loss.backward()
#      37         optimizer.step()
#      38
#
# /usr/local/lib/python3.6/dist-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     196                 products. Defaults to ``False``.
#     197         """
# --> 198         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     199
#     200     def register_hook(self, hook):
#
# /usr/local/lib/python3.6/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      98     Variable._execution_engine.run_backward(
#      99         tensors, grad_tensors, retain_graph, create_graph,
# --> 100         allow_unreachable=True)  # allow_unreachable flag
#     101
#     102
#
# KeyboardInterrupt:

# %%
plt.plot(losses)
plt.savefig('losses_with_new_loss_100e_on_samples.png')

# stopped learning at some point.

# %%
for img in samples_evolution_sk:
  imshow(img)

# %%
x = torch.rand(3,2).cuda()
generated_images = new_model2.forward(x)
for img in generated_images:
  imshow(img)
# not really a mnist digit, but not noise either
# problem is that it gives always the same image.
